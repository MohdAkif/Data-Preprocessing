# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd

#loading the bank data into pandas lib

ds=pd.read_csv('bank-full.csv',sep=';',na_values='unknown')
X=ds.iloc[:,0:16].values
y=ds.iloc[:,-1].values

#checking whether any data is empty or not

'''print(ds.isnull().sum())'''

#create a temp variable to store a column having nan values

temp=pd.DataFrame(X[:,[1,3,8,15]])

#checking the max repeated value for replacing the nan value

'''temp[0].value_counts()
temp[1].value_counts()
temp[2].value_counts()
temp[3].value_counts()'''

temp[0]=temp[0].fillna('blue-collar')
temp[1]=temp[1].fillna('secondary')
temp[2]=temp[2].fillna('cellular')
temp[3]=temp[3].fillna('failure')

#putting the value of temp into X

X[:,[1,3,8,15]]=temp

#encoding the column one by one because LabelEncoding cannot suppport more than
#one at a time

from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
 
X[:,1]=lab.fit_transform(X[:,1].astype(str))
X[:,2]=lab.fit_transform(X[:,2].astype(str))
X[:,3]=lab.fit_transform(X[:,3].astype(str))
X[:,4]=lab.fit_transform(X[:,4].astype(str))
X[:,6]=lab.fit_transform(X[:,6].astype(str))
X[:,7]=lab.fit_transform(X[:,7].astype(str))
X[:,8]=lab.fit_transform(X[:,8].astype(str))
X[:,10]=lab.fit_transform(X[:,10].astype(str))
X[:,15]=lab.fit_transform(X[:,15].astype(str))

lab.classes_

y=lab.fit_transform(y.astype(str))
lab.classes_ 

#making a sparse matrix of encoded values for the prevention of Dumy variable trap

from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder(categorical_features=[1,2,3,4,6,7,8,10,15])
X=one.fit_transform(X)
X=X.toarray()
one=OneHotEncoder()
y=y.reshape(1,-1)
y=one.fit_transform(y)
y=y.toarray()

#making a limited range of X values 

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-586884b21a6a> in <module>
#       5 #loading the bank data into pandas lib
#       6
# ----> 7 ds=pd.read_csv('bank-full.csv',sep=';',na_values='unknown')
#       8 X=ds.iloc[:,0:16].values
#       9 y=ds.iloc[:,-1].values
#
# ...
